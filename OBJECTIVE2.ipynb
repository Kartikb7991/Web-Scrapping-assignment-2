# %%
import pandas as pd
import requests
    
from selenium import webdriver
from bs4 import BeautifulSoup

from selenium.webdriver.chrome.options import Options
chrome_options = Options()
chrome_options.add_argument('--incognito')

# %%
driver=webdriver.Chrome(r"C:\Users\karti\OneDrive\Desktop\Data trained\chromedriver.exe")

# %%
driver.get("https://www.naukri.com/")

# %%
search_title=driver.find_element_by_id('qsb-keyword-sugg')
search_title.send_keys('Data Scientist')

# %%
search_location=driver.find_element_by_id('qsb-location-sugg')
search_location.send_keys('Bangalore')

# %%
search_button=driver.find_element_by_xpath('//div[@class="search-btn"]')
search_button.click()

# %%
Title=[]
Location=[]
Company=[]
Description=[]

# %%
title=driver.find_elements_by_xpath('//a[@class="title fw500 ellipsis"]')
for i in title:
    titles=i.text
    Title.append(titles)

# %%
location=driver.find_elements_by_xpath('//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in location:
    loc=i.text
    Location.append(loc)

# %%
company=driver.find_elements_by_xpath('//a[@class="subTitle ellipsis fleft"]')
for i in company:
    comp=i.text
    Company.append(comp)

# %%
description=driver.find_elements_by_xpath('//div[@class="job-description fs12 grey-text"]')
for i in description:
    des=i.text
    Description.append(des)

# %%
obj2=pd.DataFrame({})
obj2['Title']=Title
obj2['Location']=Location
obj2['Company']=Company
obj2['Description']=Description

# %%
obj2
# Out:
#                                                 Title  \
# 0   Fresher Data Engineer / Data Scientist / Data ...
# 1                         Data Scientist/Data Analyst
# 2   Data Scientist - Python/MATLAB/Machine Learnin...
# 3   Lead Data Scientist - Machine Learning/Data Mi...
# 4       Data Scientist - Machine Learning/Data Mining
# 5                   Data Scientist - Machine Learning
# 6              Senior Data Scientist - NLP/ Python/ R
# 7   Senior Data Scientist | CES IT LTD | CMMI Level 5
# 8   Senior Data Scientist | CES IT LTD | CMMI Level 5
# 9   Data Scientist - Machine Learning - Remote Wor...
# 10     Artificial Intelligence Analyst/Data Scientist
# 11                                     Data Scientist
# 12                      Global Medical Data Scientist
# 13                Advanced Architect - Data Scientist
# 14           AI Resident Data Scientist Stats. Consl.
# 15                       AI Resident - Data Scientist
# 16                       Data Scientist (ON Contract)
# 17                       Data Scientist (ON Contract)
# 18                                     Data Scientist
# 19             Looking For Data scientist - Bangalore
#
#                                              Location  \
# 0                     Delhi NCR, Bengaluru, Hyderabad
# 1                 Chennai, Pune, Bengaluru, Hyderabad
# 2                                           Bengaluru
# 3                                           Bengaluru
# 4                                           Bengaluru
# 5                                           Bengaluru
# 6                                Bengaluru, Hyderabad
# 7   Chennai, Pune, Delhi NCR, Mumbai, Bengaluru, H...
# 8   Chennai, Pune, Delhi NCR, Mumbai, Bengaluru, H...
# 9             Delhi NCR, Bengaluru, Anywhere in India
# 10                                  Mumbai, Bengaluru
# 11  Chennai, Pune, Mumbai, Bengaluru, Hyderabad, K...
# 12                                   Bengaluru, India
# 13                                          Bengaluru
# 14                                          Bengaluru
# 15                                          Bengaluru
# 16                                          Bengaluru
# 17                                          Bengaluru
# 18                      Chennai, Bengaluru, Hyderabad
# 19                       Mumbai, Bengaluru, Hyderabad
#
#                                               Company  \
# 0                       ACHYUTAS SOFT PRIVATE LIMITED
# 1   CAIA-Center For Artificial Intelligence & Adva...
# 2                        Wrackle Technologies Pvt Ltd
# 3                        Wrackle Technologies Pvt Ltd
# 4                                    Minions Ventures
# 5                   BLUE YONDER INDIA PRIVATE LIMITED
# 6                                  AVI Consulting LLP
# 7                                            CES Ltd.
# 8                                            CES Ltd.
# 9                                            Doji Ltd
# 10                            TalentCo Search Pvt Ltd
# 11                            Mailkit Private Limited
# 12            GlaxoSmithKline Pharmaceuticals Limited
# 13                                    Mphasis Limited
# 14                Shell India Markets Private Limited
# 15                Shell India Markets Private Limited
# 16                             Sandvik Asia Pvt. Ltd.
# 17                             Sandvik Asia Pvt. Ltd.
# 18                Virtusa Consulting Services Pvt Ltd
# 19               Element Infomatics (India) Pvt. Ltd.
#
#                                           Description
# 0   Building and iterating reports (with eventual ...
# 1   In case you are trying to shift your career to...
# 2   BS / MS/PhD in Computer Science, Statistics, A...
# 3   BS / MS/PhD in Computer Science, Statistics, A...
# 4   Required Skills : - Advanced degree in Machine...
# 5   Experience working with some of the following ...
# 6   Experience with application development practi...
# 7   Logical and Analytical skills must be really s...
# 8   Logical and Analytical skills must be really s...
# 9   Direct experience in performing statistical an...
# 10  Should have at-least 1 end-to-end ML project e...
# 11  Candidates might get the opportunity to work f...
# 12  medical voice of customer feedback, customer l...
# 13  Experience working with enterprise architectur...
# 14  Roles and ResponsibilitiesThe RoleThe world fa...
# 15  Preferably expertise Deep Learning, Bayesian L...
# 16  The main responsibilities are as follows: Rese...
# 17  The main responsibilities are as follows: Rese...
# 18  The ideal candidate is an experienced technolo...
# 19  Candidate should be:The ideal candidate will c...
